# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# # Ibrahim Aljadani

# %% [markdown]
# # What is Sentiment Analysis?
#
# Sentiment analysis or known as opinion mining is analyzes  and  classifies  the  sentiments, emotions, and opinions  about  any  particular  topics  or  entity  which  are  expressed  in  the  form  of  text  or  speech.
# In essence, it is the process of determining the emotional tone behind a series of words, used to gain an understanding of the the attitudes, opinions and emotions expressed within an online mention.

# %% [markdown]
# # Why we need Sentiment Analysis?
#
# Due  to  large volume of textual data increasing on the web so much of the current research is focusing on the area of sentiment analysis. Sentiment analysis is extremely useful in social media monitoring as it allows us to gain an overview of the wider public opinion behind certain topics.
#
# Because text messaging cannot accurately convey tone, emotion, facial expressions, gestures, body language, eye contact, oral speech, or face-to-face conversation, it is likely messages will be misinterpreted or misunderstood.
# The real meaning of the message gets lost through the medium.

# %% [markdown]
# # Data Collection

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install nest_asyncio

# !pip install async-timeout
# !pip install aiodns


# !pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint


# !pip install --upgrade --user -e git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# !pip install vaderSentiment

# %%
# !pip install nest_asyncio
# !pip3 install twint
# !pip install whatthelang
# !pip install optimus
# !pip install wordcloud

# %%
# !pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint

# %%
# import twint
import nest_asyncio
nest_asyncio.apply()

import sys, os
sys.path.append("twint/")

# from optimus import Optimus
# op = Optimus()

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import nltk
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import re
import string

# %%
# Set up TWINT config
# c = twint.Config()

# %%
# c.Search = "midterm elections 2022"
# # c.Format = "Username: {username} |  Tweet: {tweet}"
# c.Since = "2021-01-01"
# c.Limit = 100000
# c.Lang = 'en'
# c.Store_object = True
# c.Store_csv = True
# c.Pandas = True
# c.Output_csv = True
# c.Output = 'Midterms2022.csv'

# %%
# twint.run.Search(c)

# %%
# print('Total tweets: ', len(twint.storage.panda.Tweets_df.index))
# print('Number of colunas: ', str(len(twint.storage.panda.Tweets_df.columns)), '\n')

# %%
# def available_columns():
#     return twint.output.panda.Tweets_df.columns

# %%
# def twint_to_pandas(columns):
#     return twint.output.panda.Tweets_df[columns]

# %%
# twint.storage.panda.Tweets_df.head(2)

# %%
# df_pd = twint_to_pandas(["date", "username", "tweet", "hashtags", "nlikes"])

# %%
# df_pd

# %%
# class HiddenPrints:
#     def __enter__(self):
#         self._original_stdout = sys.stdout
#         sys.stdout = open(os.devnull, 'w')

#     def __exit__(self, exc_type, exc_val, exc_tb):
#         sys.stdout.close()
#         sys.stdout = self._original_stdout

# %%
# def get_tweets(search, limit=10000000):
#     c = twint.Config()
#     c.Search = search
#     c.Limit = limit
#     # c.Year = "2021"
#     c.Lang = 'en'
#     c.Since= "2020-01-01 00:00:00"
# #     c.Until = week
#     c.Pandas = True
#     c.Pandas_clean = True

#     with HiddenPrints():
#         print(twint.run.Search(c))
#     return twint.output.panda.Tweets_df

# %%
# from datetime import date, timedelta

# def allFriday(year):
#    d = date(year, 1, 1)                    
#    d += timedelta(days = 4 - d.weekday())  
#    while d.year == year:
#       yield d
#       d += timedelta(days = 7)

# %%
# dd= []
# for d in allFriday(2021):
#    print(d)

# %%
# weeks = [
# "2021-01-08 00:00:00",
# "2021-01-15 00:00:00",
# "2021-01-22 00:00:00",
# "2021-01-29 00:00:00",
# "2021-02-05 00:00:00",
# "2021-02-12 00:00:00",
# "2021-02-19 00:00:00",
# "2021-02-26 00:00:00",
# "2021-03-05 00:00:00",
# "2021-03-12 00:00:00",
# "2021-03-19 00:00:00",
# "2021-03-26 00:00:00",
# "2021-04-02 00:00:00",
# "2021-04-09 00:00:00",
# "2021-04-16 00:00:00",
# "2021-04-23 00:00:00",
# "2021-04-30 00:00:00",
# "2021-05-07 00:00:00",
# "2021-05-14 00:00:00",
# "2021-05-21 00:00:00",
# "2021-05-28 00:00:00",
# "2021-06-04 00:00:00",
# "2021-06-11 00:00:00",
# "2021-06-18 00:00:00",
# "2021-06-25 00:00:00",
# "2021-07-02 00:00:00",
# "2021-07-09 00:00:00",
# "2021-07-16 00:00:00",
# "2021-07-23 00:00:00",
# "2021-07-30 00:00:00",
# "2021-08-06 00:00:00",
# "2021-08-13 00:00:00",
# "2021-08-20 00:00:00",
# "2021-08-27 00:00:00",
# "2021-09-03 00:00:00",
# "2021-09-10 00:00:00",
# "2021-09-17 00:00:00",
# "2021-09-24 00:00:00",
# "2021-10-01 00:00:00",
# "2021-10-08 00:00:00",
# "2021-10-15 00:00:00",
# "2021-10-22 00:00:00",
# "2021-10-29 00:00:00",
# "2021-11-05 00:00:00",
# "2021-11-12 00:00:00",
# "2021-11-19 00:00:00",
# "2021-11-26 00:00:00",
# "2021-12-03 00:00:00",
# "2021-12-10 00:00:00",
# "2021-12-17 00:00:00",
# "2021-12-24 00:00:00",
# "2021-12-31 00:00:00"]

# key_words = ["midterm elections","2022 Senate elections","midterm elections 2022"]

# %%
# for i in weeks:
#     tweets_5 = get_tweets("Metaverse",i)

# %%
# tweets_6 = pd.DataFrame()

# %%
# tweets_6 = get_tweets("web3")

# %%
# print('Total tweets_3: ', len(tweets_6.index))

# %%
# tweets_6.to_csv(r'/Users/ibrahimaljadani/Downloads/web3.csv')

# %%
# web3 = pd.read_csv("/Users/ibrahimaljadani/Downloads/web3.csv",
#                  lineterminator='\n')
# NFT = pd.read_csv("/Users/ibrahimaljadani/Downloads/NFT.csv",
#                  lineterminator='\n')
# Metaverse = pd.read_csv("/Users/ibrahimaljadani/Downloads/Metaverse.csv",
#                  lineterminator='\n')
# cryptocurrency = pd.read_csv("/Users/ibrahimaljadani/Downloads/cryptocurrency.csv",
#                  lineterminator='\n')

# %%
# web3.head(3)

# %%
# NFT.head(3)

# %%
# Metaverse.head(3)

# %%
# cryptocurrency.head(3)

# %%
# web3 = web3.drop(columns=['id', 'conversation_id', 'created_at','cashtags', 'user_id', 'timezone',
#        'place',
#        'user_id_str',  'name', 'day', 'hour', 'link', 'urls',
#        'photos', 'video', 'thumbnail', 'retweet',  'nreplies',
#        'nretweets', 'quote_url', 'near', 'geo', 'source',
#        'user_rt_id', 'user_rt', 'retweet_id', 'reply_to', 'retweet_date',
#        'translate', 'trans_src', 'trans_dest'])

# %%
# NFT = NFT.drop(columns=['id', 'conversation_id', 'created_at','cashtags', 'user_id', 'timezone',
#        'place',
#        'user_id_str',  'name', 'day', 'hour', 'link', 'urls',
#        'photos', 'video', 'thumbnail', 'retweet',  'nreplies',
#        'nretweets', 'quote_url', 'near', 'geo', 'source',
#        'user_rt_id', 'user_rt', 'retweet_id', 'reply_to', 'retweet_date',
#        'translate', 'trans_src', 'trans_dest'])

# %%
# Metaverse = Metaverse.drop(columns=['id', 'conversation_id', 'created_at','cashtags', 'user_id', 'timezone',
#        'place',
#        'user_id_str',  'name', 'day', 'hour', 'link', 'urls',
#        'photos', 'video', 'thumbnail', 'retweet',  'nreplies',
#        'nretweets', 'quote_url', 'near', 'geo', 'source',
#        'user_rt_id', 'user_rt', 'retweet_id', 'reply_to', 'retweet_date',
#        'translate', 'trans_src', 'trans_dest'])

# %%
# cryptocurrency = cryptocurrency.drop(columns=['id', 'conversation_id', 'created_at','cashtags', 'user_id', 'timezone',
#        'place',
#        'user_id_str',  'name', 'day', 'hour', 'link', 'urls',
#        'photos', 'video', 'thumbnail', 'retweet',  'nreplies',
#        'nretweets', 'quote_url', 'near', 'geo', 'source',
#        'user_rt_id', 'user_rt', 'retweet_id', 'reply_to', 'retweet_date',
#        'translate', 'trans_src', 'trans_dest'])

# %%
# web3 = web3[['date', 'username', 'tweet', 'hashtags', 'nlikes','language', 'search']]
# NFT = NFT[['date', 'username', 'tweet', 'hashtags', 'nlikes','language', 'search']]
# Metaverse = Metaverse[['date', 'username', 'tweet', 'hashtags', 'nlikes','language', 'search']]
# cryptocurrency = cryptocurrency[['date', 'username', 'tweet', 'hashtags', 'nlikes','language', 'search']]

# %%
# web3 = web3[web3['language'].isin(['en'])]
# NFT = NFT[NFT['language'].isin(['en'])]
# Metaverse = Metaverse[Metaverse['language'].isin(['en'])]
# cryptocurrency = cryptocurrency[cryptocurrency['language'].isin(['en'])]

# %%
# web3['date'] = pd.to_datetime(web3['date'])
# web3['time'],web3['date']= web3['date'].apply(lambda x:x.time()), web3['date'].apply(lambda x:x.date())

# NFT['date'] = pd.to_datetime(NFT['date'])
# NFT['time'],NFT['date']= NFT['date'].apply(lambda x:x.time()), NFT['date'].apply(lambda x:x.date())

# Metaverse['date'] = pd.to_datetime(Metaverse['date'])
# Metaverse['time'],Metaverse['date']= Metaverse['date'].apply(lambda x:x.time()), Metaverse['date'].apply(lambda x:x.date())

# cryptocurrency['date'] = pd.to_datetime(cryptocurrency['date'])
# cryptocurrency['time'],cryptocurrency['date']= cryptocurrency['date'].apply(lambda x:x.time()), cryptocurrency['date'].apply(lambda x:x.date())

# %%
# web3.reset_index(drop=True, inplace=True)

# NFT.reset_index(drop=True, inplace=True)

# Metaverse.reset_index(drop=True, inplace=True)

# cryptocurrency.reset_index(drop=True, inplace=True)

# %%
# web3.head(3)

# %%
# NFT.head(3)

# %%
# Metaverse.head(3)

# %%
# cryptocurrency.head(3)

# %%
# pd.concat([web3, NFT, Metaverse, cryptocurrency]).to_csv(
#     r'/Users/ibrahimaljadani/Desktop/Fall 2021/Data Mining/WEB3/web3_tweets.csv')

# %%
# web3.to_csv(r'/Users/ibrahimaljadani/Desktop/Fall 2021/Data Mining/WEB3/web3.csv')
# NFT.to_csv(r'/Users/ibrahimaljadani/Desktop/Fall 2021/Data Mining/WEB3/NFT.csv')
# Metaverse.to_csv(r'/Users/ibrahimaljadani/Desktop/Fall 2021/Data Mining/WEB3/Metaverse.csv')
# cryptocurrency.to_csv(r'/Users/ibrahimaljadani/Desktop/Fall 2021/Data Mining/WEB3/cryptocurrency.csv')

# %%
# web3_tweets = pd.concat(
#     map(pd.read_csv, ["/Users/ibrahimaljadani/Desktop/Fall 2021/Data Mining/WEB3/web3.csv",
#                       "/Users/ibrahimaljadani/Desktop/Fall 2021/Data Mining/WEB3/NFT.csv",
#                       "/Users/ibrahimaljadani/Desktop/Fall 2021/Data Mining/WEB3/Metaverse.csv",
#                       "/Users/ibrahimaljadani/Desktop/Fall 2021/Data Mining/WEB3/cryptocurrency.csv"]), ignore_index=True)

# %%
web3_tweets = pd.read_csv("/Users/ibrahimaljadani/Desktop/Fall 2021/Data Mining/WEB3/web3_tweets.csv",
                 lineterminator='\n')

# %%
web3_tweets.head(3)
# Out:
#    Unnamed: 0                 date      username  \
# 0           0  2021-12-03 03:00:35  jobsincrypto
# 1           1  2021-12-03 03:00:25   analyseasia
# 2           2  2021-12-03 03:00:15    Forceman72
#
#                                                tweet  \
# 0  .@SetProtocol, the team behind the leading cry...
# 1  Hear @ysiu discuss what does great look like f...
# 2  @kevwuzy @Worldwide_WEB3 @GRAYCRAFTnft Thanks ...
#
#                                             hashtags  nlikes language search
# 0                                                 []       0       en   web3
# 1  ['metaverse', 'podcast', 'web3', 'crypto', 'nf...       0       en   web3
# 2                                                 []       0       en   web3

# %%
web3_tweets['date'] = pd.to_datetime(web3_tweets['date'])
web3_tweets['time'],web3_tweets['date']= web3_tweets['date'].apply(
    lambda x:x.time()),web3_tweets['date'].apply(lambda x:x.date())

# %%
web3_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203495 entries, 0 to 203494
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  203495 non-null  int64
#  1   date        203495 non-null  object
#  2   username    203495 non-null  object
#  3   tweet       203495 non-null  object
#  4   hashtags    203495 non-null  object
#  5   nlikes      203495 non-null  int64
#  6   language    203495 non-null  object
#  7   search      203495 non-null  object
#  8   time        203495 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 14.0+ MB

# %%
web3_tweets = web3_tweets.drop(columns=['Unnamed: 0'])

# %%
web3_tweets.reset_index(drop=True, inplace=True)

# %%
web3_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203495 entries, 0 to 203494
# Data columns (total 8 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   date      203495 non-null  object
#  1   username  203495 non-null  object
#  2   tweet     203495 non-null  object
#  3   hashtags  203495 non-null  object
#  4   nlikes    203495 non-null  int64
#  5   language  203495 non-null  object
#  6   search    203495 non-null  object
#  7   time      203495 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 12.4+ MB

# %%
web3_tweets.duplicated().sum()
# Out:
# 116

# %%
web3_tweets = web3_tweets.drop_duplicates()

# %%
web3_tweets.duplicated().sum()
# Out:
# 0

# %%
web3_tweets.isnull().sum()
# Out:
# date        0
# username    0
# tweet       0
# hashtags    0
# nlikes      0
# language    0
# search      0
# time        0
# dtype: int64

# %%
len(web3_tweets.username.unique())
# Out:
# 100116

# %%
len(web3_tweets.date.unique())
# Out:
# 10

# %%
web3_tweets.date.unique()
# Out:
# array([datetime.date(2021, 12, 3), datetime.date(2021, 12, 2),
#        datetime.date(2021, 12, 1), datetime.date(2021, 11, 30),
#        datetime.date(2021, 11, 29), datetime.date(2021, 11, 28),
#        datetime.date(2021, 11, 27), datetime.date(2021, 11, 26),
#        datetime.date(2021, 11, 25), datetime.date(2021, 11, 24)],
#       dtype=object)

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

text = web3_tweets.tweet.values

# adding movie script specific stopwords
stopwords = set(STOPWORDS)

wordcloud = WordCloud(
    background_color = 'white',
   
    stopwords = stopwords).generate(str(text))

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.rcParams['figure.figsize'] = [8, 8]

# %%
# clean_tweet = pd.DataFrame()
# clean_tweet["tweet"]= web3_tweets["tweet"]#.str.replace("[^a-zA-Z0-9]", " ")
# clean_tweet["tweet"]= clean_tweet["tweet"].str.replace("http\S+", " ")
# clean_tweet["tweet"]= clean_tweet["tweet"].str.replace("@\w+", "")

# %%
def clean_text_fun(tweet):
    tweet = tweet.lower() # text lowercase
    tweet = re.sub('@[^\s]+', '', tweet) # remove usernames
    tweet = re.sub('\[.*?\]', '', tweet) # remove square brackets
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', '', tweet) # remove URLs
    tweet = re.sub('[%s]' % re.escape(string.punctuation), '', tweet) # remove punctuation
    tweet = re.sub('\w*\d\w*', '', tweet) 
    tweet = re.sub('[‘’“”…]', '', tweet)
    tweet = re.sub('\n', '', tweet)
    return tweet

    
tweet = lambda x: clean_text_fun(x)

# %%
clean_tweet = pd.DataFrame(web3_tweets.tweet.apply(tweet))
# clean_tweet

# %%
clean_tweet
# Out:
#                                                     tweet
# 0        the team behind the leading crypto asset mana...
# 1       hear  discuss what does great look like for  a...
# 2                             thanks a lot join guys
# 3       take a look at yesterdays top  ethereum nfts b...
# 4        zo the vibe isnt meme enough try again  its s...
# ...                                                   ...
# 203490     i choice  in doge coin  because i need some...
# 203491    cyber monday special  sol     officially ver...
# 203492     project is very good and this projector has...
# 203493  new series game characters will be added every...
# 203494       i believed this amazing project will burn...
#
# [203379 rows x 1 columns]

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

text_2 = clean_tweet.tweet.values

# adding movie script specific stopwords
stopwords = set(STOPWORDS)

wordcloud_2 = WordCloud(
    background_color = 'white',
   
    stopwords = stopwords).generate(str(text_2))

# %%
plt.imshow(wordcloud_2, interpolation='bilinear')
plt.axis("off")
plt.rcParams['figure.figsize'] = [8, 8]

# %%
def tokenize(text):
    tokens = re.split("\W+", text)
    return tokens
clean_tweet['tweet']= clean_tweet['tweet'].apply (lambda x: tokenize(x.lower()))

# %%
nltk.download("stopwords")
nltk.download('wordnet')
nltk.download('vader_lexicon')
# stopwords = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ibrahimaljadani/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/ibrahimaljadani/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/ibrahimaljadani/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
def remove_stopword(text):
    text_nostopword= [char for char in text if char not in stopwords]
    return text_nostopword

clean_tweet['tweet']= clean_tweet['tweet'].apply(lambda x: remove_stopword(x))

# %%
clean_tweet
# Out:
#                                                     tweet
# 0       [, team, behind, leading, crypto, asset, manag...
# 1       [hear, discuss, great, look, focuses, true, di...
# 2                           [, thanks, lot, join, guys, ]
# 3       [take, look, yesterdays, top, ethereum, nfts, ...
# 4       [, zo, vibe, isnt, meme, enough, try, simple, ...
# ...                                                   ...
# 203490  [, choice, doge, coin, need, moneycryptocurren...
# 203491  [, cyber, monday, special, sol, officially, ve...
# 203492  [, project, good, projector, lot, attractions,...
# 203493  [new, series, game, characters, will, added, e...
# 203494  [, believed, amazing, project, will, burning, ...
#
# [203379 rows x 1 columns]

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer

wnl = WordNetLemmatizer()
def lemmatize(s):
  s = [wnl.lemmatize(word) for word in s]
  return s
clean_tweet = clean_tweet.assign(lemmatize = clean_tweet.tweet.apply(lambda x: lemmatize(x)))

# %%
clean_tweet
# Out:
#                                                     tweet  \
# 0       [, team, behind, leading, crypto, asset, manag...
# 1       [hear, discuss, great, look, focuses, true, di...
# 2                           [, thanks, lot, join, guys, ]
# 3       [take, look, yesterdays, top, ethereum, nfts, ...
# 4       [, zo, vibe, isnt, meme, enough, try, simple, ...
# ...                                                   ...
# 203490  [, choice, doge, coin, need, moneycryptocurren...
# 203491  [, cyber, monday, special, sol, officially, ve...
# 203492  [, project, good, projector, lot, attractions,...
# 203493  [new, series, game, characters, will, added, e...
# 203494  [, believed, amazing, project, will, burning, ...
#
#                                                 lemmatize
# 0       [, team, behind, leading, crypto, asset, manag...
# 1       [hear, discus, great, look, focus, true, digit...
# 2                            [, thanks, lot, join, guy, ]
# ...

# %%
# Porter Stemmer
ps= nltk.PorterStemmer()


# stemming 

def stem(tweet_no_stopword):
   text = [ps.stem ( word) for word in tweet_no_stopword]
   return text

clean_tweet["stemmer"]= clean_tweet["tweet"].apply(lambda x: stem(x))

# %%
clean_tweet
# Out:
#                                                     tweet  \
# 0       [, team, behind, leading, crypto, asset, manag...
# 1       [hear, discuss, great, look, focuses, true, di...
# 2                           [, thanks, lot, join, guys, ]
# 3       [take, look, yesterdays, top, ethereum, nfts, ...
# 4       [, zo, vibe, isnt, meme, enough, try, simple, ...
# ...                                                   ...
# 203490  [, choice, doge, coin, need, moneycryptocurren...
# 203491  [, cyber, monday, special, sol, officially, ve...
# 203492  [, project, good, projector, lot, attractions,...
# 203493  [new, series, game, characters, will, added, e...
# 203494  [, believed, amazing, project, will, burning, ...
#
#                                                 lemmatize  \
# 0       [, team, behind, leading, crypto, asset, manag...
# 1       [hear, discus, great, look, focus, true, digit...
# 2                            [, thanks, lot, join, guy, ]
# ...

# %%
# clean_tweet['tweet'] = clean_tweet['tweet'].apply(lambda x: ' '.join([w for w in x]))
# clean_tweet['lemmatize'] = clean_tweet['lemmatize'].apply(lambda x: ' '.join([w for w in x]))
clean_tweet['stemmer'] = clean_tweet['stemmer'].apply(lambda x: ' '.join([w for w in x]))
clean_tweet.head()
# Out:
#                                                tweet  \
# 0  [, team, behind, leading, crypto, asset, manag...
# 1  [hear, discuss, great, look, focuses, true, di...
# 2                      [, thanks, lot, join, guys, ]
# 3  [take, look, yesterdays, top, ethereum, nfts, ...
# 4  [, zo, vibe, isnt, meme, enough, try, simple, ...
#
#                                            lemmatize  \
# 0  [, team, behind, leading, crypto, asset, manag...
# 1  [hear, discus, great, look, focus, true, digit...
# 2                       [, thanks, lot, join, guy, ]
# 3  [take, look, yesterday, top, ethereum, nfts, s...
# 4  [, zo, vibe, isnt, meme, enough, try, simple, ...
#
#                                              stemmer
# 0   team behind lead crypto asset manag protocol ...
# 1  hear discuss great look focus true digit owner...
# 2                                thank lot join guy
# 3  take look yesterday top ethereum nft sale pull...
# 4   zo vibe isnt meme enough tri simpl post meme ...

# %%
data_list = clean_tweet.loc[:,"tweet"].to_list()
len(data_list)
# Out:
# 203379

# %%
flat_data_list = [item for sublist in data_list for item in sublist]
len(flat_data_list)
# Out:
# 2777027

# %%
data_count= pd.DataFrame(flat_data_list)
data_count= data_count[0].value_counts()
data_count

# data_count= pd.DataFrame(data_list)
# data_count= data_count[0].value_counts()
# data_count
# Out:
#                   201187
# cryptocurrency     81584
# project            62325
# metaverse          50364
# will               41227
#                    ...
# barkkkk                1
# emty                   1
# comienza               1
# carey                  1
# buyallaltcoins         1
# Name: 0, Length: 79899, dtype: int64

# %%
from nltk.probability import FreqDist
freq_count= FreqDist()
for words in data_count:
  freq_count[words] +=1

freq_count
# Out:
# FreqDist({1: 40975, 2: 10485, 3: 5038, 4: 3224, 5: 2160, 6: 1700, 7: 1323, 8: 1005, 9: 933, 10: 740, ...})

# %%
data_count = data_count[1:15,]
plt.figure(figsize=(10,5))
sns.barplot(data_count.values, data_count.index, alpha=1)
plt.title('Top Words Overall')
plt.ylabel('Word from Tweet', fontsize=12)
plt.xlabel('Count of Words', fontsize=12)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Time_Of_tweet = pd.DataFrame()
Time_Of_tweet = web3_tweets.time.apply(lambda x: x.hour)

# %%
Time_Of_tweet.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# sample_tweet = clean_tweet.sample(100)

# %%
# sample_tweet

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
def sentiment_analyze(stemmer):
  score = SentimentIntensityAnalyzer().polarity_scores(stemmer)
  neg = score['neg'] 
  pos = score['pos']
  neu = score['neu']

  return SentimentIntensityAnalyzer().polarity_scores(stemmer)

# %%
clean_tweet['label_1']  = clean_tweet['stemmer'].apply(sentiment_analyze)
clean_tweet['compound'] = clean_tweet['label_1'].apply(lambda d:d['compound'])
clean_tweet['label_2']  = clean_tweet['compound'].apply(lambda score: 'positive' if score>=0.05 else 'negative' if score<=-0.05 else 'neutral')
clean_tweet

# sample_tweet['label_1']  = sample_tweet['stemmer'].apply(sentiment_analyze)
# sample_tweet['compound'] = sample_tweet['label_1'].apply(lambda d:d['compound'])
# sample_tweet['label_2']  = sample_tweet['compound'].apply(lambda score: 'positive' if score>=0.05 else 'negative' if score<=-0.05 else 'neutral')
# sample_tweet
# Out:
#                                                     tweet  \
# 0       [, team, behind, leading, crypto, asset, manag...
# 1       [hear, discuss, great, look, focuses, true, di...
# 2                           [, thanks, lot, join, guys, ]
# 3       [take, look, yesterdays, top, ethereum, nfts, ...
# 4       [, zo, vibe, isnt, meme, enough, try, simple, ...
# ...                                                   ...
# 203490  [, choice, doge, coin, need, moneycryptocurren...
# 203491  [, cyber, monday, special, sol, officially, ve...
# 203492  [, project, good, projector, lot, attractions,...
# 203493  [new, series, game, characters, will, added, e...
# 203494  [, believed, amazing, project, will, burning, ...
#
#                                                 lemmatize  \
# 0       [, team, behind, leading, crypto, asset, manag...
# 1       [hear, discus, great, look, focus, true, digit...
# 2                            [, thanks, lot, join, guy, ]
# ...

# %%
clean_tweet['search'] = web3_tweets['search']
clean_tweet['date'] = web3_tweets['date']
clean_tweet['time'] = web3_tweets['time']
clean_tweet
# Out:
#                                                     tweet  \
# 0       [, team, behind, leading, crypto, asset, manag...
# 1       [hear, discuss, great, look, focuses, true, di...
# 2                           [, thanks, lot, join, guys, ]
# 3       [take, look, yesterdays, top, ethereum, nfts, ...
# 4       [, zo, vibe, isnt, meme, enough, try, simple, ...
# ...                                                   ...
# 203490  [, choice, doge, coin, need, moneycryptocurren...
# 203491  [, cyber, monday, special, sol, officially, ve...
# 203492  [, project, good, projector, lot, attractions,...
# 203493  [new, series, game, characters, will, added, e...
# 203494  [, believed, amazing, project, will, burning, ...
#
#                                                 lemmatize  \
# 0       [, team, behind, leading, crypto, asset, manag...
# 1       [hear, discus, great, look, focus, true, digit...
# 2                            [, thanks, lot, join, guy, ]
# ...

# %%
# from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# def sentiment_scores(sentence):

# 	# Create a SentimentIntensityAnalyzer object.
# 	sid_obj = SentimentIntensityAnalyzer()

# 	# polarity_scores method of SentimentIntensityAnalyzer
# 	# object gives a sentiment dictionary.
# 	# which contains pos, neg, neu, and compound scores.
# 	sentiment_dict = sid_obj.polarity_scores(sentence)
	
# 	# print("Overall sentiment dictionary is : ", sentiment_dict)
# 	# print("sentence was rated as ", sentiment_dict['neg']*100, "% Negative")
# 	# print("sentence was rated as ", sentiment_dict['neu']*100, "% Neutral")
# 	# print("sentence was rated as ", sentiment_dict['pos']*100, "% Positive")

# 	# print("Sentence Overall Rated As", end = " ")

# 	# decide sentiment as positive, negative and neutral
# 	if sentiment_dict['compound'] >= 0.05 :
# 		return("Positive")

# 	elif sentiment_dict['compound'] <= - 0.05 :
# 		return("Negative")

# 	else :
# 		return("Neutral")

# %%
# web3_tweets['label_2'] = clean_tweet['tweet'].map(lambda x: sentiment_scores(x))

# %%
# web3_tweets

# %%
clean_tweet.groupby('label_2').count()
# sample_tweet.groupby('label_2').count()
# Out:
#            tweet  lemmatize  stemmer  label_1  compound  search    date  \
# label_2
# negative   23410      23410    23410    23410     23410   23410   23410
# neutral    78504      78504    78504    78504     78504   78504   78504
# positive  101465     101465   101465   101465    101465  101465  101465
#
#             time
# label_2
# negative   23410
# neutral    78504
# positive  101465

# %%
clean_tweet['label_2'].value_counts().plot(kind='barh')
# sample_tweet['label_2'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,16))
sns.countplot(y='label_2', hue='search', data = clean_tweet)
plt.legend(loc='center right', title='search Type')

# %%
sns.catplot(x="label_2", hue="search", col="search",
                data=clean_tweet, kind="count" , height=4, aspect=.6);

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import svm
from sklearn.metrics  import accuracy_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import cluster
from sklearn import tree

# %%
sentiment_counts = clean_tweet.label_2.value_counts()
print(sentiment_counts)
# Out:
# positive    101465
# neutral      78504
# negative     23410
# Name: label_2, dtype: int64

# %%
test_set_1 = clean_tweet[:30000]

# %%
X_train_1, X_val_1, y_train_1, y_val_1 = train_test_split(clean_tweet['stemmer'][120000:], 
                                                  clean_tweet['label_2'][120000:], 
                                                  test_size=0.2)

# Sentiment za test set
y_test_1 = test_set_1['label_2']

# %%
vectorizer = TfidfVectorizer()
X_train_1 = vectorizer.fit_transform(X_train_1)
X_val_1 = vectorizer.transform(X_val_1)
X_test_1 = vectorizer.transform(test_set_1['stemmer'])

# %%
print(f'Training size: {X_train_1.shape[0]} tweets\n\
Validation size: {X_val_1.shape[0]} tweets\n\
Test size: {X_test_1.shape[0]} tweets\n\
Amount of words (columns): {X_train_1.shape[1]} words')
# Out:
# Training size: 66703 tweets
# Validation size: 16676 tweets
# Test size: 30000 tweets
# Amount of words (columns): 31694 words

# %%
multi_nb_1 = MultinomialNB()
multi_nb_1.fit(X_train_1, y_train_1)
# Out:
# MultinomialNB()

# %%
mnb_train_pred_1 = multi_nb_1.predict(X_train_1)
mnb_val_pred_1 = multi_nb_1.predict(X_val_1)
print(f'Accuracy on training set (MultinomialNB): {round(accuracy_score(y_train_1, mnb_train_pred_1)*100, 2)}%')
print(f'Accuracy on validation set (MultinomialNB): {round(accuracy_score(y_val_1,mnb_val_pred_1)*100, 2)}%')
# Out:
# Accuracy on training set (MultinomialNB): 85.1%
# Accuracy on validation set (MultinomialNB): 81.76%

# %%
svc_1 = svm.SVC()
svc_1.fit(X_train_1,y_train_1)
# Out:
# SVC()

# %%
svc_train_pred_1 = svc_1.predict(X_train_1)
svc_val_pred_1 = svc_1.predict(X_val_1)
print(f'Accuracy on training set (SVC): {round(accuracy_score(y_train_1, svc_train_pred_1)*100, 2)}%')
print(f'Accuracy on validation set (SVC): {round(accuracy_score(y_val_1,svc_val_pred_1)*100, 2)}%')
# Out:
# Accuracy on training set (SVC): 99.37%
# Accuracy on validation set (SVC): 94.81%

# %%
gbm_1 = GradientBoostingClassifier(n_estimators=1000, 
                                 max_depth=6) 
                              
gbm_1.fit(X_train_1,y_train_1)
# Out:
# GradientBoostingClassifier(max_depth=6, n_estimators=1000)

# %%
gbm_train_pred_1 = gbm_1.predict(X_train_1)
gbm_val_pred_1 = gbm_1.predict(X_val_1)
print(f'Accuracy on training set (GBM): {round(accuracy_score(y_train_1, gbm_train_pred_1)*100, 2)}%')
print(f'Accuracy on validation set (GBM): {round(accuracy_score(y_val_1,gbm_val_pred_1)*100, 2)}%')
# Out:
# Accuracy on training set (GBM): 99.54%
# Accuracy on validation set (GBM): 96.84%

# %%
crf_1 = RandomForestClassifier()
crf_1.fit(X_train_1,y_train_1)
# Out:
# RandomForestClassifier()

# %%
crf_train_pred_1 = crf_1.predict(X_train_1)
crf_val_pred_1 = crf_1.predict(X_val_1)
print(f'Accuracy on training set (RFC): {round(accuracy_score(y_train_1, crf_train_pred_1)*100, 2)}%')
print(f'Accuracy on validation set (RFC): {round(accuracy_score(y_val_1,crf_val_pred_1)*100, 2)}%')
# Out:
# Accuracy on training set (RFC): 100.0%
# Accuracy on validation set (RFC): 93.99%

# %%
clf_1 = tree.DecisionTreeClassifier()
clf_1.fit(X_train_1,y_train_1)
# Out:
# DecisionTreeClassifier()

# %%
clf_train_pred_1 = clf_1.predict(X_train_1)
clf_val_pred_1 = clf_1.predict(X_val_1)
print(f'Accuracy on training set (DTC): {round(accuracy_score(y_train_1, clf_train_pred_1)*100, 2)}%')
print(f'Accuracy on validation set (DTC): {round(accuracy_score(y_val_1,clf_val_pred_1)*100, 2)}%')
# Out:
# Accuracy on training set (DTC): 100.0%
# Accuracy on validation set (DTC): 95.48%

# %%
multinb_test_pred_1 = multi_nb_1.predict(X_test_1)

# Support Vector Machine 
svc_test_pred_1 = svc_1.predict(X_test_1)

# Gradient Boosting Classifier
gbm_test_pred_1 = gbm_1.predict(X_test_1)

# Random Forest Classifier
rfc_test_pred_1 = crf_1.predict(X_test_1)

# Decision Tree Classifier
dtc_test_pred_1 = clf_1.predict(X_test_1)

# %%
print(f'Accuracy for Multinomial Naive Bayes: {round(accuracy_score(y_test_1, multinb_test_pred_1)*100, 4)}%')
print(f'Accuracy for Support Vector Machine: {round(accuracy_score(y_test_1, svc_test_pred_1)*100, 4)}%')
print(f'Accuracy for Gradient Boosting Classifier: {round(accuracy_score(y_test_1, gbm_test_pred_1)*100, 4)}%')
print(f'Accuracy for Random Forest Classifier: {round(accuracy_score(y_test_1, rfc_test_pred_1)*100, 4)}%')
print(f'Accuracy for Decision Tree Classifier: {round(accuracy_score(y_test_1, dtc_test_pred_1)*100, 4)}%')
# Out:
# Accuracy for Multinomial Naive Bayes: 64.19%
# Accuracy for Support Vector Machine: 90.34%
# Accuracy for Gradient Boosting Classifier: 93.3867%
# Accuracy for Random Forest Classifier: 88.3733%
# Accuracy for Decision Tree Classifier: 89.9767%

# %%
clean_tweet_2 = clean_tweet.sample(frac=1).reset_index(drop=True)
clean_tweet_2
# Out:
#                                                     tweet  \
# 0                         [metrics, measuring, happiness]
# 1       [, time, join, metaverse, world, thats, way, n...
# 2       [excited, announce, special, nft, giveaway, pa...
# 3       [drop, questions, dm, give, indepth, thoughts,...
# 4       [onboarding, someone, rather, people, change, ...
# ...                                                   ...
# 203374  [features, interoperability, teleporting, natu...
# 203375  [dont, need, lot, money, started, crypto, inve...
# 203376  [top, performing, cryptocurrency, hour, wluna,...
# 203377  [, glad, really, know, whats, best, certainly,...
# 203378  [miss, chance, first, holders, meto, token, me...
#
#                                                 lemmatize  \
# 0                          [metric, measuring, happiness]
# 1       [, time, join, metaverse, world, thats, way, n...
# 2       [excited, announce, special, nft, giveaway, pa...
# ...

# %%
test_set_2 = clean_tweet_2[:30000]

# %%
X_train_2, X_val_2, y_train_2, y_val_2 = train_test_split(clean_tweet_2['stemmer'][120000:], 
                                                  clean_tweet_2['label_2'][120000:], 
                                                  test_size=0.2)

# Sentiment za test set
y_test_2 = test_set_2['label_2']

# %%
vectorizer = TfidfVectorizer()
X_train_2 = vectorizer.fit_transform(X_train_2)
X_val_2 = vectorizer.transform(X_val_2)
X_test_2 = vectorizer.transform(test_set_2['stemmer'])

# %%
print(f'Training size: {X_train_2.shape[0]} tweets\n\
Validation size: {X_val_2.shape[0]} tweets\n\
Test size: {X_test_2.shape[0]} tweets\n\
Amount of words (columns): {X_train_2.shape[1]} words')
# Out:
# Training size: 66703 tweets
# Validation size: 16676 tweets
# Test size: 30000 tweets
# Amount of words (columns): 34828 words

# %%
multi_nb_2 = MultinomialNB()
multi_nb_2.fit(X_train_2, y_train_2)
# Out:
# MultinomialNB()

# %%
mbn_train_pred_2 = multi_nb_2.predict(X_train_2)
mbn_val_pred_2 = multi_nb_2.predict(X_val_2)
print(f'Accuracy on training set (MultinomialNB): {round(accuracy_score(y_train_2, mbn_train_pred_2)*100, 2)}%')
print(f'Accuracy on validation set (MultinomialNB): {round(accuracy_score(y_val_2,mbn_val_pred_2)*100, 2)}%')
# Out:
# Accuracy on training set (MultinomialNB): 80.71%
# Accuracy on validation set (MultinomialNB): 75.71%

# %%
svc_2 = svm.SVC()
svc_2.fit(X_train_2,y_train_2)
# Out:
# SVC()

# %%
svc_train_pred_2 = svc_2.predict(X_train_2)
svc_val_pred_2 = svc_2.predict(X_val_2)
print(f'Accuracy on training set (SVC): {round(accuracy_score(y_train_2, svc_train_pred_2)*100, 2)}%')
print(f'Accuracy on validation set (SVC): {round(accuracy_score(y_val_2,svc_val_pred_2)*100, 2)}%')
# Out:
# Accuracy on training set (SVC): 99.13%
# Accuracy on validation set (SVC): 93.86%

# %%
gbm_2 = GradientBoostingClassifier(n_estimators=1000, 
                                 max_depth=6) 
                              
gbm_2.fit(X_train_2, y_train_2)
# Out:
# GradientBoostingClassifier(max_depth=6, n_estimators=1000)

# %%
gbm_train_pred_2 = gbm_2.predict(X_train_2)
gbm_val_pred_2 = gbm_2.predict(X_val_2)
print(f'Accuracy on training set (GBM): {round(accuracy_score(y_train_2, gbm_train_pred_2)*100, 2)}%')
print(f'Accuracy on validation set (GBM): {round(accuracy_score(y_val_2,gbm_val_pred_2)*100, 2)}%')
# Out:
# Accuracy on training set (GBM): 98.99%
# Accuracy on validation set (GBM): 95.85%

# %%
crf_2 = RandomForestClassifier()
crf_2.fit(X_train_2, y_train_2)
# Out:
# RandomForestClassifier()

# %%
crf_train_pred_2 = crf_2.predict(X_train_2)
crf_val_pred_2 = crf_2.predict(X_val_2)
print(f'Accuracy on training set (RFC): {round(accuracy_score(y_train_2, crf_train_pred_2)*100, 2)}%')
print(f'Accuracy on validation set (RFC): {round(accuracy_score(y_val_2,crf_val_pred_2)*100, 2)}%')
# Out:
# Accuracy on training set (RFC): 100.0%
# Accuracy on validation set (RFC): 93.27%

# %%
clf_2 = tree.DecisionTreeClassifier()
clf_2.fit(X_train_2, y_train_2)
# Out:
# DecisionTreeClassifier()

# %%
clf_train_pred_2 = clf_2.predict(X_train_2)
clf_val_pred_2 = clf_2.predict(X_val_2)
print(f'Accuracy on training set (DTC): {round(accuracy_score(y_train_2, clf_train_pred_2)*100, 2)}%')
print(f'Accuracy on validation set (DTC): {round(accuracy_score(y_val_2,clf_val_pred_2)*100, 2)}%')
# Out:
# Accuracy on training set (DTC): 100.0%
# Accuracy on validation set (DTC): 95.03%

# %%
multinb_test_pred_2 = multi_nb_2.predict(X_test_2)

# Support Vector Machine 
svc_test_pred_2 = svc_2.predict(X_test_2)

# Gradient Boosting Classifier
gbm_test_pred_2 = gbm_2.predict(X_test_2)

# Random Forest Classifier
rfc_test_pred_2 = crf_2.predict(X_test_2)

# Decision Tree Classifier
dtc_test_pred_2 = clf_2.predict(X_test_2)

# %%
print(f'Accuracy for Multinomial Naive Bayes: {round(accuracy_score(y_test_1, multinb_test_pred_1)*100, 2)}%')
print(f'Accuracy for Support Vector Machine: {round(accuracy_score(y_test_1, svc_test_pred_1)*100, 2)}%')
print(f'Accuracy for Gradient Boosting Classifier: {round(accuracy_score(y_test_1, gbm_test_pred_1)*100, 2)}%')
print(f'Accuracy for Random Forest Classifier: {round(accuracy_score(y_test_1, rfc_test_pred_1)*100, 2)}%')
print(f'Accuracy for Decision Tree Classifier: {round(accuracy_score(y_test_1, dtc_test_pred_1)*100, 2)}%')
# Out:
# Accuracy for Multinomial Naive Bayes: 64.19%
# Accuracy for Support Vector Machine: 90.34%
# Accuracy for Gradient Boosting Classifier: 93.39%
# Accuracy for Random Forest Classifier: 88.37%
# Accuracy for Decision Tree Classifier: 89.98%

# %%
print(f'Accuracy for Multinomial Naive Bayes: {round(accuracy_score(y_test_2, multinb_test_pred_2)*100, 2)}%')
print(f'Accuracy for Support Vector Machine: {round(accuracy_score(y_test_2, svc_test_pred_2)*100, 2)}%')
print(f'Accuracy for Gradient Boosting Classifier: {round(accuracy_score(y_test_2, gbm_test_pred_2)*100, 2)}%')
print(f'Accuracy for Random Forest Classifier: {round(accuracy_score(y_test_2, rfc_test_pred_2)*100, 2)}%')
print(f'Accuracy for Decision Tree Classifier: {round(accuracy_score(y_test_2, dtc_test_pred_2)*100, 2)}%')
# Out:
# Accuracy for Multinomial Naive Bayes: 75.99%
# Accuracy for Support Vector Machine: 93.93%
# Accuracy for Gradient Boosting Classifier: 96.02%
# Accuracy for Random Forest Classifier: 93.44%
# Accuracy for Decision Tree Classifier: 95.1%
